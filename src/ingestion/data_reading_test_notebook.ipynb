# %%
import importlib
import data_reading

importlib.reload(data_reading)
from data_reading import read_file

# %%
# Ordner, in dem dieses Python-Skript liegt
BASE_DIR = Path.cwd()

# Datei im gleichen Ordner
csv1_file_path = BASE_DIR / "synth_cases_icd10_ops.csv"
csv2_file_path = BASE_DIR / "clinic_1_epaAC-Data.csv"
xlsx_file_path = BASE_DIR / "synth_device_motion_fall.xlsx"

df_csv1 = read_file(csv1_file_path)
df_csv2 = read_file(csv2_file_path)
df_xlsx = read_file(xlsx_file_path)

# print(df_csv1.success)
# print(df_csv1.metadata["separator"])

# df_csv1.data.head() # Zeigt die ersten Zeilen des DataFrames aus der CSV-Datei
# print(df_xlsx.issues)  # Zeigt an, ob das Einlesen der Excel-Datei erfolgreich war
df_xlsx.data.head()  # Zeigt die ersten Zeilen des DataFrames aus der Excel
# Out:
#   patient_id,timestamp,movement_index_0_100,micro_movements_count,bed_exit_detected_0_1,fall_event_0_1,impact_magnitude_g,post_fall_immobility_minutes
# 0         PAT-0018,2026-01-01 01:00:00,NULL,22,0,0,,
# 1                  ,2026-01-01 01:00:00,8.7,16,0,0,,
# 2         PAT-0044,2026-01-01 01:00:00,73.5,74,0,0,,
# 3         PAT-0083,2026-01-01 01:00:00,52.0,44,0,0,,
# 4         PAT-0098,2026-01-01 01:00:00,36.3,56,0,0,,

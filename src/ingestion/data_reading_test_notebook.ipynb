# %%
import importlib
import data_reading_llm

importlib.reload(data_reading_llm)
from data_reading_llm import read_file

# %%
# Ordner, in dem dieses Python-Skript liegtt
BASE_DIR = Path.cwd()

# Datei im gleichen Ordner
csv1_file_path = BASE_DIR / "epaAC-Data-3.csv"
csv2_file_path = BASE_DIR / "clinic_1_epaAC-Data.csv"
xlsx_file_path = BASE_DIR / "synth_device_motion_fall.xlsx"

df_csv1 = read_file(csv1_file_path)
df_csv2 = read_file(csv2_file_path)
df_xlsx = read_file(xlsx_file_path)

print(df_csv1.success)
print(df_csv1.metadata["separator"])

df_csv1.data.head() # Zeigt die ersten Zeilen des DataFrames aus der CSV-Datei
# print(df_xlsx.issues)  # Zeigt an, ob das Einlesen der Excel-Datei erfolgreich war
# df_xlsx.data.head()  # Zeigt die ersten Zeilen des DataFrames aus der Excel
# Out:
# True
# ;
#   EinschIDFall               FallNr (STRING)     AufnDat  AufnZeit EntlassDat  \
# 0     E2_I_226  E2_I_222 (E3_I_0889)(STRING)    E2_I_223  E2_I_224   E2_I_228
# 1        22836                            99  20.01.2026  07:59:00        NaN
# 2        22837                            99  20.01.2026  07:59:00        NaN
# 3        22838                           796  20.01.2026  08:13:00        NaN
# 4        22839                           796  20.01.2026  08:13:00        NaN
#
#   EntlassZeit   EinschDat EinschZeit           FaBerFaAbt (STRING)  \
# 0    E2_I_229    E2_I_225   E2_I_227  E2_I_230 (E3_I_0896)(STRING)
# 1         NaN  01.02.2026   08:12:07                         ABT01
# 2         NaN  01.02.2026   08:26:27                         ABT01
# 3         NaN  01.02.2026   08:42:18                         ABT01
# 4         NaN  01.02.2026   08:46:32                         ABT01
#
#                StatBez (STRING)  ...   Unnamed: 578  \
# 0  E2_I_232 (E3_I_0898)(STRING)  ...  ZDat_E2_I_081
# 1                        STAT01  ...            NaN
# 2                        STAT01  ...            NaN
# 3                        STAT01  ...            NaN
# 4                        STAT01  ...            NaN
#
#   Fähigkeit sich zu beschäftigen   Unnamed: 580   Unnamed: 581  \
# 0                       E2_I_076  ZWrt_E2_I_076  ZDat_E2_I_076
# 1                            NaN            NaN            NaN
# 2                            NaN            NaN            NaN
# 3                            NaN            NaN            NaN
# 4                            NaN            NaN            NaN
#
#   Langzeitbeatmung Abklärungserfordernis Depression  \
# 0         E2_I_088                         E0_I_079
# 1              NaN                              NaN
# 2              NaN                              NaN
# 3              NaN                              NaN
# 4              NaN                              NaN
#
#   Dekubitus_interne Referenz Dekubitus_interne Referenz.1  \
# 0        E2_I_166 (intRef)_1          E2_I_166 (intRef)_2
# 1                        NaN                          NaN
# 2                        NaN                          NaN
# 3                        NaN                          NaN
# 4                        NaN                          NaN
#
#   Wunden/ path. Hautveränderungen_interne Referenz  \
# 0                              E2_I_052 (intRef)_1
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   Wunden/ path. Hautveränderungen_interne Referenz.1
# 0                                E2_I_052 (intRef)_2
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 588 columns]

# %%
print(df_csv1.issues)
# Out:
# []
